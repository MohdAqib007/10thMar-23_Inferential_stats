# %%
#Q1: What is Estimation Statistics? Explain point estimate and interval estimate.
#Ans-
'''Estimation statistics is a branch of statistics that deals with making predictions or inferences about a population based on sample data. 
It involves using statistical methods to estimate population parameters such as means, variances, and proportions.

Point Estimate:
A point estimate is a single value that is used to estimate an unknown population parameter. 
It is obtained by calculating a statistic, such as the sample mean or sample proportion, from a sample of data. 
For example, the sample mean of a group of 50 students’ test scores can be used as a point estimate of the population mean test score.

Interval Estimate:
An interval estimate is a range of values that is used to estimate an unknown population parameter. 
It is obtained by calculating a confidence interval, which is a range of values that is likely to contain the true population parameter with a certain level of confidence. 
For example, a 95% confidence interval for the population mean test score would be a range of values calculated from the sample data that is likely to contain the true mean test score with a 95% level of confidence.'''

# %%
#Q2. Write a Python function to estimate the population mean using a sample mean and standard deviation.
#Ans-
'''Sure, here's an example Python function that estimates the population mean using a sample mean and standard deviation:'''

import math

def estimate_population_mean(sample_mean, sample_std_dev, sample_size):
    """Estimates the population mean using a sample mean and standard deviation"""
    # Calculate the standard error of the mean
    std_err = sample_std_dev / math.sqrt(sample_size)
    # Calculate the lower and upper bounds of the 95% confidence interval
    lower_bound = sample_mean - 1.96 * std_err
    upper_bound = sample_mean + 1.96 * std_err
    # Return the estimated population mean and confidence interval
    return sample_mean, (lower_bound, upper_bound)

# %%
'''To use this function, you would need to provide it with the sample mean, sample standard deviation, and sample size as arguments. 
The function then calculates the standard error of the mean, which is the standard deviation of the sampling distribution of the mean. 
It then calculates the lower and upper bounds of the 95% confidence interval using the formula sample_mean +/- 1.96 * std_err, where 1.96 is the z-score corresponding to a 95% confidence interval.

Here's an example usage of the function:'''

# Example usage
sample_mean = 10.5
sample_std_dev = 2.3
sample_size = 100
population_mean, confidence_interval = estimate_population_mean(sample_mean, sample_std_dev, sample_size)
print(f"Estimated population mean: {population_mean:.2f}")
print(f"95% Confidence interval: {confidence_interval}")

#This means that we estimate the population mean to be around 10.5, with a 95% confidence interval ranging from 10.01 to 10.99.
# Out:
# Estimated population mean: 10.50
# 95% Confidence interval: (10.0492, 10.9508)

# %%
#Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.
#Ans-
'''Hypothesis testing is a statistical method used to evaluate whether a statement or claim about a population parameter is likely to be true or not, based on sample data. 
It involves setting up two competing hypotheses, the null hypothesis (H0) and the alternative hypothesis (Ha), and then using sample data to either accept or reject the null hypothesis.

The null hypothesis is the statement that there is no significant difference between a population parameter and a hypothesized value. 
The alternative hypothesis is the statement that there is a significant difference between a population parameter and a hypothesized value.

Hypothesis testing is used to make decisions based on sample data when the population parameters are unknown. 
It allows us to test the validity of assumptions, make conclusions about the population based on a sample, and determine if observed differences between samples are statistically significant or due to chance.

The importance of hypothesis testing lies in its ability to provide a framework for making objective and evidence-based decisions. 
It helps to avoid making decisions based on intuition or personal bias and provides a way to test the validity of claims made about population parameters.

Hypothesis testing is widely used in many fields such as medicine, engineering, business, social sciences, and more. 
It is used to test hypotheses about population means, variances, proportions, and more. By using hypothesis testing, researchers and practitioners can make more informed decisions and draw conclusions based on solid statistical evidence.'''

# %%
#Q4. Create a hypothesis that states whether the average weight of male college students is greater than the average weight of female college students.
#Ans-
'''Here's an example hypothesis that states whether the average weight of male college students is greater than the average weight of female college students:

Null Hypothesis (H0): The average weight of male college students is equal to or less than the average weight of female college students.

Alternative Hypothesis (Ha): The average weight of male college students is greater than the average weight of female college students.

In this hypothesis, the null hypothesis states that there is no significant difference between the average weight of male and female college students, or that the average weight of male college students is equal to or less than the average weight of female college students. 
The alternative hypothesis states that the average weight of male college students is greater than the average weight of female college students.

This hypothesis could be tested by collecting weight data from a random sample of male and female college students, calculating the sample means and variances, and performing a hypothesis test to determine if the difference between the sample means is statistically significant.'''

# %%
#Q5. Write a Python script to conduct a hypothesis test on the difference between two population means, given a sample from each population.
#Ans-
'''Here's an example Python script to conduct a hypothesis test on the difference between two population means, given a sample from each population:'''

import numpy as np
from scipy import stats

# Generate two random samples from normal distributions with different means and variances
sample1 = np.random.normal(loc=10, scale=2, size=50)
sample2 = np.random.normal(loc=12, scale=3, size=50)

# Conduct a two-sample t-test to test if the difference between the sample means is statistically significant
t_stat, p_val = stats.ttest_ind(sample1, sample2)

# Print the test results
print("Test results:")
print(f"t-statistic: {t_stat:.3f}")
print(f"p-value: {p_val:.3f}")

# Interpret the results
alpha = 0.05
if p_val < alpha:
    print(f"The p-value of {p_val:.3f} is less than the significance level of {alpha}.")
    print("We reject the null hypothesis that the two population means are equal.")
    print("There is strong evidence to suggest that the population means are different.")
else:
    print(f"The p-value of {p_val:.3f} is greater than the significance level of {alpha}.")
    print("We fail to reject the null hypothesis that the two population means are equal.")
    print("There is no strong evidence to suggest that the population means are different.")
# Out:
# Test results:
# t-statistic: -3.128
# p-value: 0.002
# The p-value of 0.002 is less than the significance level of 0.05.
# We reject the null hypothesis that the two population means are equal.
# There is strong evidence to suggest that the population means are different.

# %%
'''In this script, we first generate two random samples from normal distributions with different means and variances using the NumPy library. 
We then use the ttest_ind function from the SciPy library to conduct a two-sample t-test, which tests if the difference between the sample means is statistically significant.

We then print the test results, including the t-statistic and p-value. Finally, we interpret the results by comparing the p-value to a significance level (alpha) of 0.05. 
If the p-value is less than alpha, we reject the null hypothesis that the two population means are equal and conclude that there is strong evidence to suggest that the population means are different. 
If the p-value is greater than alpha, we fail to reject the null hypothesis and conclude that there is no strong evidence to suggest that the population means are different.'''

# %%
#Q6: What is a null and alternative hypothesis? Give some examples.
#Ans-
'''In hypothesis testing, a null hypothesis (H0) is a statement that assumes there is no significant difference between two populations or that there is no relationship between two variables. 
The alternative hypothesis (Ha) is a statement that assumes there is a significant difference between two populations or that there is a relationship between two variables.

Here are some examples of null and alternative hypotheses:

1. Null Hypothesis: The mean IQ score of a population is equal to 100.
Alternative Hypothesis: The mean IQ score of a population is not equal to 100.

2. Null Hypothesis: There is no difference in the effectiveness of two different drugs.
Alternative Hypothesis: One drug is more effective than the other.

3. Null Hypothesis: The proportion of people who support a political candidate is 50%.
Alternative Hypothesis: The proportion of people who support a political candidate is greater than or less than 50%.

4. Null Hypothesis: There is no correlation between hours of study and exam performance.
Alternative Hypothesis: There is a positive or negative correlation between hours of study and exam performance.

5. Null Hypothesis: The average wait time for customers at a restaurant is 10 minutes or less.
Alternative Hypothesis: The average wait time for customers at a restaurant is more than 10 minutes.

In each of these examples, the null hypothesis assumes that there is no significant difference or relationship, while the alternative hypothesis assumes that there is a significant difference or relationship.'''

# %%
#Q7: Write down the steps involved in hypothesis testing.
#Ans-
'''Here are the general steps involved in hypothesis testing:

1. State the null hypothesis and alternative hypothesis: Define the null hypothesis (H0) and alternative hypothesis (Ha) based on the research question or problem being investigated.

2. Set the significance level: Choose a significance level (alpha) that represents the maximum probability of making a Type I error (rejecting the null hypothesis when it is true). A common value for alpha is 0.05.

3. Determine the test statistic and the critical value: Choose an appropriate test statistic based on the data and assumptions of the test. 
Calculate the critical value based on the chosen alpha level, degrees of freedom, and distribution of the test statistic.

4. Collect and analyze the data: Collect a sample of data and calculate the test statistic based on the sample data. Determine the p-value associated with the test statistic.

5. Make a decision and draw a conclusion: Compare the p-value to the chosen significance level. If the p-value is less than or equal to the significance level, reject the null hypothesis and accept the alternative hypothesis. 
If the p-value is greater than the significance level, fail to reject the null hypothesis.

6. Interpret the results: Interpret the results in the context of the research question or problem being investigated. Draw conclusions and make recommendations based on the results.

7. Check assumptions and validity: Check the assumptions of the hypothesis test and ensure that the test is valid for the given data and research question. 
Consider any limitations or weaknesses of the test and address them as needed.

These steps can be applied to a variety of hypothesis tests, including tests for means, proportions, variances, and correlations.'''

# %%
#Q8. Define p-value and explain its significance in hypothesis testing.
#Ans-
'''The p-value is a probability value that represents the likelihood of observing a test statistic as extreme as or more extreme than the one calculated from the sample data, assuming the null hypothesis is true. 
In hypothesis testing, the p-value is used to make a decision about whether to reject or fail to reject the null hypothesis.

If the p-value is less than or equal to the chosen significance level (alpha), typically 0.05, then we reject the null hypothesis and accept the alternative hypothesis. 
This means that the observed data provides strong evidence against the null hypothesis and supports the alternative hypothesis.

On the other hand, if the p-value is greater than the chosen significance level, we fail to reject the null hypothesis. 
This means that the observed data does not provide strong enough evidence to reject the null hypothesis, and we cannot conclude that there is a significant difference or relationship between the variables being tested.

The significance of the p-value in hypothesis testing lies in its ability to quantify the strength of the evidence against the null hypothesis. 
A smaller p-value indicates stronger evidence against the null hypothesis, while a larger p-value indicates weaker evidence. 
By using the p-value to make decisions about rejecting or failing to reject the null hypothesis, we can draw valid conclusions and make informed decisions based on the results of the hypothesis test.'''

# %%
#Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom parameter set to 10.
#Ans-
'''Here's an example Python code to generate a Student's t-distribution plot with 10 degrees of freedom using the matplotlib library:'''

import numpy as np
import matplotlib.pyplot as plt

# Set the degrees of freedom
df = 10

# Define the range of x values for the t-distribution
x = np.linspace(-4, 4, 1000)

# Calculate the corresponding y values for the t-distribution
y = np.exp(-x ** 2 / 2) / np.sqrt(2 * np.pi) / np.sqrt(df) / np.power(1 + x ** 2 / df, (df + 1) / 2)

# Create the plot
plt.plot(x, y)
plt.title("Student's t-distribution (df=10)")
plt.xlabel("x")
plt.ylabel("Probability density")
plt.show()

# %%
#This code defines the degrees of freedom (df) as 10, and then generates a range of x values for the t-distribution using the linspace function from numpy. 
#It then calculates the corresponding y values for the t-distribution using the probability density function of the t-distribution. 
#Finally, it creates the plot using the plot function from matplotlib, and sets the title, xlabel, and ylabel using the title, xlabel, and ylabel functions respectively.
#The resulting plot shows the probability density function of the Student's t-distribution with 10 degrees of freedom.

# %%
#Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two random samples of equal size and a null hypothesis that the population means are equal.
#Ans-
'''This code generates two random samples using the normal function from numpy, assuming that the population means are 10 and 12, and the standard deviations are 2 for both populations. 
It then calculates the means and standard deviations of the two samples, and uses them to calculate the pooled standard deviation. 
It then calculates the t-statistic using the formula (mean1 - mean2) / (pooled_std * np.sqrt(2 / len(sample1))). 
The degrees of freedom are calculated as df = len(sample1) + len(sample2) - 2. Finally, the p-value is calculated using the t.cdf function from the stats module of scipy. The results are printed to the console.

Note that in this example, we assume that the variances of the two populations are equal, which is why we use the pooled standard deviation. 
If the variances are not equal, we need to use a modified version of the t-test called the Welch's t-test, which does not assume equal variances.'''

import numpy as np
from scipy import stats

# Generate two random samples with equal size
sample1 = np.random.normal(loc=10, scale=2, size=50)
sample2 = np.random.normal(loc=12, scale=2, size=50)

# Calculate the means and standard deviations of the two samples
mean1 = np.mean(sample1)
mean2 = np.mean(sample2)
std1 = np.std(sample1, ddof=1)
std2 = np.std(sample2, ddof=1)

# Calculate the pooled standard deviation
pooled_std = np.sqrt(((len(sample1) - 1) * std1 ** 2 + (len(sample2) - 1) * std2 ** 2) / (len(sample1) + len(sample2) - 2))

# Calculate the t-statistic
t_statistic = (mean1 - mean2) / (pooled_std * np.sqrt(2 / len(sample1)))

# Calculate the degrees of freedom
df = len(sample1) + len(sample2) - 2

# Calculate the p-value
p_value = 2 * stats.t.cdf(-np.abs(t_statistic), df)

# Print the results
print("Sample 1 mean: {:.2f}".format(mean1))
print("Sample 2 mean: {:.2f}".format(mean2))
print("Pooled standard deviation: {:.2f}".format(pooled_std))
print("t-statistic: {:.2f}".format(t_statistic))
print("p-value: {:.4f}".format(p_value))
# Out:
# Sample 1 mean: 9.95
# Sample 2 mean: 12.23
# Pooled standard deviation: 1.94
# t-statistic: -5.88
# p-value: 0.0000

# %%
#Q11: What is Student’s t distribution? When to use the t-Distribution.
#Ans-

'''Student's t-distribution, also known as the t-distribution, is a probability distribution that arises when we want to estimate the mean of a normally distributed population, but only have a small sample size. 
It is used when the population variance is unknown, and the sample size is small, typically less than 30. 
The t-distribution is similar in shape to the normal distribution, but has heavier tails, which means that it has more probability in the tails and less probability in the center, compared to the normal distribution.

We use the t-distribution when we want to perform a hypothesis test on a population mean, but only have a small sample size. 
The t-distribution is used instead of the normal distribution because the sample standard deviation is used to estimate the population standard deviation, which can introduce more uncertainty into the calculation. 
As the sample size increases, the t-distribution approaches the normal distribution, and we can use the normal distribution instead. The t-distribution is also used in confidence interval calculations for the same reason.

Overall, the t-distribution is an important tool in statistics that allows us to make inferences about population parameters when we have small sample sizes and/or unknown population variances.
'''

# %%
#Q12: What is t-statistic? State the formula for t-statistic.
#Ans-

'''The t-statistic is a test statistic that is used to test hypotheses about population means, when the population standard deviation is unknown and the sample size is small. 
The t-statistic measures the difference between the sample mean and the hypothesized population mean, in units of the standard error of the sample mean.

The formula for the t-statistic is:

t = (x̄ - μ) / (s / sqrt(n))

where:

x̄ is the sample mean
μ is the hypothesized population mean under the null hypothesis
s is the sample standard deviation
n is the sample size
The numerator (x̄ - μ) measures the difference between the sample mean and the hypothesized population mean, while the denominator (s / sqrt(n)) measures the standard error of the sample mean, which is a measure of the variability of sample means that we would expect to see if we took repeated samples from the same population.

If the calculated t-statistic is large enough, we reject the null hypothesis and conclude that the sample mean is significantly different from the hypothesized population mean. The critical value of t depends on the degrees of freedom, which is n-1 for a one-sample t-test. 
We compare the calculated t-value to the critical value of t, and if the calculated t-value is larger than the critical value of t, we reject the null hypothesis.'''

# %%
#Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of $50. Estimate the population mean revenue with a 95% confidence interval.
#Ans-
'''To estimate the population mean revenue with a 95% confidence interval, we can use the following formula:

CI = x̄ ± t(alpha/2, n-1) * (s / sqrt(n))

where:

x̄ is the sample mean revenue
t(alpha/2, n-1) is the t-value from the t-distribution with n-1 degrees of freedom, and alpha/2 area in the tails
s is the sample standard deviation
n is the sample size
alpha is the significance level, which is 1 - confidence level
Since we want a 95% confidence interval, the significance level is alpha = 1 - 0.95 = 0.05, and the degrees of freedom are n-1 = 50-1 = 49. Using a t-table or calculator, we can find the t-value with 0.025 area in the tails, which is approximately 2.009.

Plugging in the values, we get:

CI = 500 ± 2.009 * (50 / sqrt(50))
CI = 500 ± 14.18

Therefore, the 95% confidence interval for the population mean revenue is (500 - 14.18, 500 + 14.18), or approximately ($485.82, $514.18). 
We can interpret this as: we are 95% confident that the true population mean revenue is between $485.82 and $514.18, based on our sample of 50 days.'''

# %%
#Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.
#Ans-

'''To test the hypothesis that the new drug will decrease blood pressure by 10 mmHg, we can set up the following null and alternative hypotheses:

H0: µ = 10 (the drug has no effect on blood pressure)
Ha: µ < 10 (the drug decreases blood pressure)

We will use a one-sample t-test with a significance level of 0.05 to test this hypothesis.

The t-statistic for this test can be calculated using the formula:

t = (x̄ - µ) / (s / sqrt(n))

where:

x̄ is the sample mean decrease in blood pressure, which is 8 mmHg
µ is the hypothesized mean decrease in blood pressure under the null hypothesis, which is 10 mmHg
s is the sample standard deviation, which is 3 mmHg
n is the sample size, which is 100
Plugging in the values, we get:

t = (8 - 10) / (3 / sqrt(100))
t = -2 * sqrt(100) / 3
t = -6.67

Using a t-table or calculator, we can find the p-value associated with this t-value and degrees of freedom (n-1 = 99). The p-value is less than 0.0001, which is much smaller than the significance level of 0.05. Therefore, we reject the null hypothesis and conclude that the new drug decreases blood pressure. We can also conclude that the mean decrease in blood pressure is significantly less than 10 mmHg.

In conclusion, there is sufficient evidence to suggest that the new drug decreases blood pressure by more than 10 mmHg with a significance level of 0.05.'''

# %%
#Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight is found to be 4.8 pounds.  Test the hypothesis that the true mean weight of the products is less than 5 pounds with a significance level of 0.01.
#Ans-

'''To test the hypothesis that the true mean weight of the products is less than 5 pounds, we can set up the following null and alternative hypotheses:

H0: µ = 5 (the true mean weight is 5 pounds)
Ha: µ < 5 (the true mean weight is less than 5 pounds)

We will use a one-sample t-test with a significance level of 0.01 to test this hypothesis.

The t-statistic for this test can be calculated using the formula:

t = (x̄ - µ) / (s / sqrt(n))

where:

x̄ is the sample mean weight, which is 4.8 pounds
µ is the hypothesized true mean weight under the null hypothesis, which is 5 pounds
s is the sample standard deviation, which is 0.5 pounds
n is the sample size, which is 25
Plugging in the values, we get:

t = (4.8 - 5) / (0.5 / sqrt(25))
t = -2

Using a t-table or calculator, we can find the p-value associated with this t-value and degrees of freedom (n-1 = 24). The p-value is 0.028, which is less than the significance level of 0.01. Therefore, we reject the null hypothesis and conclude that the true mean weight of the products is less than 5 pounds.

In conclusion, there is sufficient evidence to suggest that the true mean weight of the products is less than 5 pounds with a significance level of 0.01.'''

# %%
#Q16. Two groups of students are given different study materials to prepare for a test. The first group (n1 = 30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two groups are equal with a significance level of 0.01.
#Ans-
'''To test the hypothesis that the population means for the two groups are equal, we can set up the following null and alternative hypotheses:

H0: µ1 = µ2 (the population means for the two groups are equal)
Ha: µ1 ≠ µ2 (the population means for the two groups are not equal)

We will use a two-sample t-test with a significance level of 0.01 to test this hypothesis.

The t-statistic for this test can be calculated using the formula:

t = (x̄1 - x̄2) / sqrt(s1^2/n1 + s2^2/n2)

where:

x̄1 and x̄2 are the sample means for the two groups, which are 80 and 75, respectively
s1 and s2 are the sample standard deviations for the two groups, which are 10 and 8, respectively
n1 and n2 are the sample sizes for the two groups, which are 30 and 40, respectively
Plugging in the values, we get:

t = (80 - 75) / sqrt(10^2/30 + 8^2/40)
t = 3.34

Using a t-table or calculator, we can find the p-value associated with this t-value and degrees of freedom (n1 + n2 - 2 = 68). The p-value is less than 0.01, which is the significance level. Therefore, we reject the null hypothesis and conclude that the population means for the two groups are not equal.

In conclusion, there is sufficient evidence to suggest that the population means for the two groups are not equal with a significance level of 0.01. This implies that the study materials given to the two groups have different effects on the test scores.'''

# %%
#Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard deviation of 1.5. Estimate the population mean with a 99% confidence interval.
#Ans-
'''To estimate the population mean with a 99% confidence interval, we can use the following formula:

Confidence interval = sample mean ± z* (standard error)

where z* is the critical value from the standard normal distribution for a 99% confidence level (2.576), and standard error is the standard deviation of the sample divided by the square root of the sample size (n).

So, plugging in the values we have:

Confidence interval = 4 ± 2.576 * (1.5/√50)

Confidence interval = 4 ± 0.618

Therefore, the 99% confidence interval for the population mean number of ads watched by viewers during a TV program is (3.382, 4.618). We can be 99% confident that the true population mean lies within this interval.'''
